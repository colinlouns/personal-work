# %% [markdown]
# # Pandas and Pokemon
#
# ### Learning objectives:
# - Review importing data in pandas
# - Review renaming columns
# - Basic EDA and data cleaning in pandas
# - Basic sorting and filtering in pandas
# - Groupbys in pandas
#
# ## Read in the data using pandas:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('./pokedex_basic.csv')

# %%
df.head(100)
# Out:
#     PokedexNumber                       Name           Type  Total   HP  \
# 0               1                  Bulbasaur    GrassPoison    318   45
# 1               2                    Ivysaur    GrassPoison    405   60
# 2               3                   Venusaur    GrassPoison    525   80
# 3               3      VenusaurMega Venusaur    GrassPoison    625   80
# 4               4                 Charmander           Fire    309   39
# 5               5                 Charmeleon           Fire    405   58
# 6               6                  Charizard     FireFlying    534   78
# 7               6  CharizardMega Charizard X     FireDragon    634   78
# 8               6  CharizardMega Charizard Y     FireFlying    634   78
# 9               7                   Squirtle          Water    314   44
# 10              8                  Wartortle          Water    405   59
# 11              9                  Blastoise          Water    530   79
# 12              9    BlastoiseMega Blastoise          Water    630   79
# 13             10                   Caterpie            Bug    195   45
# 14             11                    Metapod            Bug    205   50
# 15             12                 Butterfree      BugFlying    395   60
# 16             13                     Weedle      BugPoison    195   40
# 17             14                     Kakuna      BugPoison    205   45
# 18             15                   Beedrill      BugPoison    395   65
# 19             15      BeedrillMega Beedrill      BugPoison    495   65
# 20             16                     Pidgey   NormalFlying    251   40
# 21             17                  Pidgeotto   NormalFlying    349   63
# 22             18                    Pidgeot   NormalFlying    479   83
# 23             18        PidgeotMega Pidgeot   NormalFlying    579   83
# 24             19                    Rattata         Normal    253   30
# 25             20                   Raticate         Normal    413   55
# 26             21                    Spearow   NormalFlying    262   40
# 27             22                     Fearow   NormalFlying    442   65
# 28             23                      Ekans         Poison    288   35
# 29             24                      Arbok         Poison    438   60
# ..            ...                        ...            ...    ...  ...
# 70             65                   Alakazam        Psychic    500   55
# 71             65      AlakazamMega Alakazam        Psychic    590   55
# 72             66                     Machop       Fighting    305   70
# 73             67                    Machoke       Fighting    405   80
# 74             68                    Machamp       Fighting    505   90
# 75             69                 Bellsprout    GrassPoison    300   50
# 76             70                 Weepinbell    GrassPoison    390   65
# 77             71                 Victreebel    GrassPoison    490   80
# 78             72                  Tentacool    WaterPoison    335   40
# 79             73                 Tentacruel    WaterPoison    515   80
# 80             74                    Geodude     RockGround    300   40
# 81             75                   Graveler     RockGround    390   55
# 82             76                      Golem     RockGround    495   80
# 83             77                     Ponyta           Fire    410   50
# 84             78                   Rapidash           Fire    500   65
# 85             79                   Slowpoke   WaterPsychic    315   90
# 86             80                    Slowbro   WaterPsychic    490   95
# 87             80        SlowbroMega Slowbro   WaterPsychic    590   95
# 88             81                  Magnemite  ElectricSteel    325   25
# 89             82                   Magneton  ElectricSteel    465   50
# 90             83                 Farfetch'd   NormalFlying    352   52
# 91             84                      Doduo   NormalFlying    310   35
# 92             85                     Dodrio   NormalFlying    460   60
# 93             86                       Seel          Water    325   65
# 94             87                    Dewgong       WaterIce    475   90
# 95             88                     Grimer         Poison    325   80
# 96             89                        Muk         Poison    500  105
# 97             90                   Shellder          Water    305   30
# 98             91                   Cloyster       WaterIce    525   50
# 99             92                     Gastly    GhostPoison    310   30
#
#     Attack  Defense  Special Attack  Special Defense  Speed
# 0       49       49              65               65     45
# 1       62       63              80               80     60
# 2       82       83             100              100     80
# 3      100      123             122              120     80
# 4       52       43              60               50     65
# 5       64       58              80               65     80
# 6       84       78             109               85    100
# 7      130      111             130               85    100
# 8      104       78             159              115    100
# 9       48       65              50               64     43
# 10      63       80              65               80     58
# 11      83      100              85              105     78
# 12     103      120             135              115     78
# 13      30       35              20               20     45
# 14      20       55              25               25     30
# 15      45       50              90               80     70
# 16      35       30              20               20     50
# 17      25       50              25               25     35
# 18      90       40              45               80     75
# 19     150       40              15               80    145
# 20      45       40              35               35     56
# 21      60       55              50               50     71
# 22      80       75              70               70    101
# 23      80       80             135               80    121
# 24      56       35              25               35     72
# 25      81       60              50               70     97
# 26      60       30              31               31     70
# 27      90       65              61               61    100
# 28      60       44              40               54     55
# 29      85       69              65               79     80
# ..     ...      ...             ...              ...    ...
# 70      50       45             135               95    120
# 71      50       65             175               95    150
# 72      80       50              35               35     35
# 73     100       70              50               60     45
# 74     130       80              65               85     55
# 75      75       35              70               30     40
# 76      90       50              85               45     55
# 77     105       65             100               70     70
# 78      40       35              50              100     70
# 79      70       65              80              120    100
# 80      80      100              30               30     20
# 81      95      115              45               45     35
# 82     120      130              55               65     45
# 83      85       55              65               65     90
# 84     100       70              80               80    105
# 85      65       65              40               40     15
# 86      75      110             100               80     30
# 87      75      180             130               80     30
# 88      35       70              95               55     45
# 89      60       95             120               70     70
# 90      65       55              58               62     60
# 91      85       45              35               35     75
# 92     110       70              60               60    100
# 93      45       55              45               70     45
# 94      70       80              70               95     70
# 95      80       50              40               50     25
# 96     105       75              65              100     50
# 97      65      100              45               25     40
# 98      95      180              85               45     70
# 99      35       30             100               35     80
#
# [100 rows x 10 columns]

# %% [markdown]
# ## Rename the SpecialAttack and SpecialDefense columns to Special Attack and Special Defense:

# %%
df = df.rename(columns = { "SpecialAttack" : "Special Attack", "SpecialDefense" : "Special Defense"})

# %% [markdown]
# ## Use inbuilt methods to figure out how many 'repeated' Pokemon there are:

# %%
df[df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [PokedexNumber, Name, Type, Total, HP, Attack, Defense, Special Attack, Special Defense, Speed]
# Index: []

# %% [markdown]
# Looks like there are no identically repeated names.  However we know the Mega evolutions are going to be "duplicates".

# %% [markdown]
# ## Some of our 'repeated' Pokemon are Mega Pokemon or Size-variant Pokemon. Use boolean masks to filter them out of the dataframe:

# %%
mega_mask = lambda 'mega': 'mega' not in df['Name']
# Out:
#   File "<ipython-input-53-d32d9086eda4>", line 1
#     mega_mask = lambda 'mega': 'mega' not in df['Name']
#                             ^
# SyntaxError: invalid syntax

# %%
df.drop_duplicates(subset = "PokedexNumber").head(10)
# Out:
#     PokedexNumber        Name         Type  Total  HP  Attack  Defense  \
# 0               1   Bulbasaur  GrassPoison    318  45      49       49
# 1               2     Ivysaur  GrassPoison    405  60      62       63
# 2               3    Venusaur  GrassPoison    525  80      82       83
# 4               4  Charmander         Fire    309  39      52       43
# 5               5  Charmeleon         Fire    405  58      64       58
# 6               6   Charizard   FireFlying    534  78      84       78
# 9               7    Squirtle        Water    314  44      48       65
# 10              8   Wartortle        Water    405  59      63       80
# 11              9   Blastoise        Water    530  79      83      100
# 13             10    Caterpie          Bug    195  45      30       35
#
#     Special Attack  Special Defense  Speed
# 0               65               65     45
# 1               80               80     60
# 2              100              100     80
# 4               60               50     65
# 5               80               65     80
# 6              109               85    100
# 9               50               64     43
# 10              65               80     58
# 11              85              105     78
# 13              20               20     45

# %%
remove_extras = []

for name in df["Name"]:
    if "Mega" in name:
        remove_extras.append(name)
    elif "Small Size" in name:
        remove_extras.append(name)
    elif "Large Size" in name:
        remove_extras.append(name)
    elif "Super Size" in name:
        remove_extras.append(name)
    elif "Unbound" in name:
        remove_extras.append(name)
        
df[~df['Name'].isin(remove_extras)].head(10)
# Out:
#     PokedexNumber        Name         Type  Total  HP  Attack  Defense  \
# 0               1   Bulbasaur  GrassPoison    318  45      49       49
# 1               2     Ivysaur  GrassPoison    405  60      62       63
# 2               3    Venusaur  GrassPoison    525  80      82       83
# 4               4  Charmander         Fire    309  39      52       43
# 5               5  Charmeleon         Fire    405  58      64       58
# 6               6   Charizard   FireFlying    534  78      84       78
# 9               7    Squirtle        Water    314  44      48       65
# 10              8   Wartortle        Water    405  59      63       80
# 11              9   Blastoise        Water    530  79      83      100
# 13             10    Caterpie          Bug    195  45      30       35
#
#     Special Attack  Special Defense  Speed
# 0               65               65     45
# 1               80               80     60
# 2              100              100     80
# 4               60               50     65
# 5               80               65     80
# 6              109               85    100
# 9               50               64     43
# 10              65               80     58
# 11              85              105     78
# 13              20               20     45

# %% [markdown]
# ## `df[df['Name'] == 'Pancham']`
#
# How does [Pancham the panda Pokemon](https://bulbapedia.bulbagarden.net/wiki/Pancham_(Pok%C3%A9mon) stack up as a fighting Pokemon? Display Pancham's stats, and compare them to the average stats for all fighting Pokemon.

# %%
df[df['Name'] == 'Pancham']
# Out:
#      PokedexNumber     Name      Type  Total  HP  Attack  Defense  \
# 742            674  Pancham  Fighting    348  67      82       62
#
#      Special Attack  Special Defense  Speed
# 742              46               48     43

# %%
df[df["Type"].isin(["Fighting"])]
# Out:
#      PokedexNumber        Name      Type  Total   HP  Attack  Defense  \
# 61              56      Mankey  Fighting    305   40      80       35
# 62              57    Primeape  Fighting    455   65     105       60
# 72              66      Machop  Fighting    305   70      80       50
# 73              67     Machoke  Fighting    405   80     100       70
# 74              68     Machamp  Fighting    505   90     130       80
# 114            106   Hitmonlee  Fighting    455   50     120       53
# 115            107  Hitmonchan  Fighting    455   50     105       79
# 255            236     Tyrogue  Fighting    210   35      35       35
# 256            237   Hitmontop  Fighting    455   50      95       95
# 320            296    Makuhita  Fighting    237   72      60       30
# 321            297    Hariyama  Fighting    474  144     120       60
# 496            447       Riolu  Fighting    285   40      70       40
# 592            532     Timburr  Fighting    305   75      80       55
# 593            533     Gurdurr  Fighting    405   85     105       85
# 594            534  Conkeldurr  Fighting    505  105     140       95
# 598            538       Throh  Fighting    465  120     100       85
# 599            539        Sawk  Fighting    465   75     125       75
# 680            619     Mienfoo  Fighting    350   45      85       50
# 681            620    Mienshao  Fighting    510   65     125       60
# 742            674     Pancham  Fighting    348   67      82       62
#
#      Special Attack  Special Defense  Speed
# 61               35               45     70
# 62               60               70     95
# 72               35               35     35
# 73               50               60     45
# 74               65               85     55
# 114              35              110     87
# 115              35              110     76
# 255              35               35     35
# 256              35              110     70
# 320              20               30     25
# 321              40               60     50
# 496              35               40     60
# 592              25               35     35
# 593              40               50     40
# 594              55               65     45
# 598              30               85     45
# 599              30               75     85
# 680              55               50     65
# 681              95               60    105
# 742              46               48     43

# %% [markdown]
# ## Best Stats
#
# Which Pokemon has the best Total, HP, Attack, Defense, SpecialAttack, SpecialDefense, and Speed stats?

# %% [markdown]
# ## What Pokemon type is most common?

# %% [markdown]
# ## Of the 12 most common Pokemon types, what Pokemon are on average strongest?

# %% [markdown]
# ## Bonus: Plot a heatmap of Pokemon type vs. average stats:

# %% [markdown]
# ## Bonus: Write a function that plots a histogram of a stat for a given Pokemon type:

# %%
# note: why would it be inadvisable to use `type` as a variable name here?
def plot_stat_of_type(stat, poke_type, df):
    pass
