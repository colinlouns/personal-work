# %%
import pandas as pd
import numpy as np
import altair as alt
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split

alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')
spray = pd.read_csv('./spray.csv')
weather = pd.read_csv('./weather.csv')

# %%
spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
# Date         14835 non-null object
# Time         14251 non-null object
# Latitude     14835 non-null float64
# Longitude    14835 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 463.7+ KB

# %%
spray = spray.dropna()

# %%
train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  10506.000000  10506.000000  10506.000000     10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.339468      0.112742      0.096514         1.452921
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent
# count  10506.000000  10506.000000
# mean      12.853512      0.052446
# std       16.133816      0.222936
# min        1.000000      0.000000
# 25%        2.000000      0.000000
# 50%        5.000000      0.000000
# 75%       17.000000      0.000000
# max       50.000000      1.000000

# %%
train.head(3)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0

# %%
train = train.drop(['Address', 'Street', 'Species', 'Block', 'AddressNumberAndStreet', 'AddressAccuracy'], axis = 1)

# %%
train.head(3)
# Out:
#          Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 0  2007-05-29  T002  41.954690 -87.800991             1           0
# 1  2007-05-29  T002  41.954690 -87.800991             1           0
# 2  2007-05-29  T007  41.994991 -87.769279             1           0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 6 columns):
# Date            10506 non-null object
# Trap            10506 non-null object
# Latitude        10506 non-null float64
# Longitude       10506 non-null float64
# NumMosquitos    10506 non-null int64
# WnvPresent      10506 non-null int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 492.5+ KB

# %%
maps = alt.Chart(train.sample(4999)).mark_circle(size = 80, opacity = 0.1).encode(
    alt.X('Longitude', title = "Longitude", scale = alt.Scale(domain=[-88.1, -87.3])),
    alt.Y('Latitude', title = "Latitude", scale = alt.Scale(domain=[41.6, 42.1])),
).properties(title= "Locations of Mosquito Traps"
).interactive(
)
maps

# %%
train = train.groupby(['Date', 'Trap', 'Latitude', 'Longitude']).sum().reset_index()

# %%
train.sort_values(['WnvPresent'], ascending = False).head(20)
# Out:
#             Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 4341  2013-08-29  T900  41.974689 -87.890615           608          12
# 743   2007-08-16  T115  41.673408 -87.599862          2636          11
# 4411  2013-09-06  T900  41.974689 -87.890615           550           9
# 4054  2013-08-01  T900  41.974689 -87.890615           984           9
# 854   2007-08-22  T138  41.726465 -87.585413          1124           7
# 851   2007-08-22  T115  41.673408 -87.599862          1615           7
# 344   2007-07-25  T115  41.673408 -87.599862          3002           5
# 3042  2011-08-12  T900  41.974689 -87.890615           246           5
# 651   2007-08-15  T016  42.011601 -87.811506           216           4
# 852   2007-08-22  T128  41.704572 -87.565666           338           4
# 963   2007-08-28  T115  41.673408 -87.599862          2476           4
# 753   2007-08-17  T221  41.659112 -87.538693           459           4
# 4056  2013-08-08  T002  41.954690 -87.800991           196           4
# 4453  2013-09-12  T115  41.673408 -87.599862           222           3
# 4552  2013-09-19  T900  41.974689 -87.890615           123           3
# 2919  2011-07-29  T900  41.974689 -87.890615           242           3
# 1052  2007-09-05  T115  41.673408 -87.599862          1648           3
# 744   2007-08-16  T128  41.704572 -87.565666           919           3
# 4274  2013-08-29  T009  41.992478 -87.862995           196           3
# 844   2007-08-22  T096  41.731922 -87.677512           128           3

# %%
train.sort_values(['NumMosquitos'], ascending = False).head(20)
# Out:
#             Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 344   2007-07-25  T115  41.673408 -87.599862          3002           5
# 743   2007-08-16  T115  41.673408 -87.599862          2636          11
# 472   2007-08-01  T115  41.673408 -87.599862          2479           0
# 963   2007-08-28  T115  41.673408 -87.599862          2476           4
# 629   2007-08-08  T138  41.726465 -87.585413          1892           2
# 1052  2007-09-05  T115  41.673408 -87.599862          1648           3
# 627   2007-08-08  T115  41.673408 -87.599862          1625           3
# 851   2007-08-22  T115  41.673408 -87.599862          1615           7
# 1699  2009-06-22  T900  41.974689 -87.890615          1596           0
# 1241  2007-09-19  T115  41.673408 -87.599862          1361           1
# 854   2007-08-22  T138  41.726465 -87.585413          1124           7
# 525   2007-08-02  T138  41.726465 -87.585413          1075           1
# 745   2007-08-16  T138  41.726465 -87.585413          1000           2
# 4054  2013-08-01  T900  41.974689 -87.890615           984           9
# 1062  2007-09-06  T115  41.673408 -87.599862           938           0
# 744   2007-08-16  T128  41.704572 -87.565666           919           3
# 346   2007-07-25  T138  41.726465 -87.585413           913           0
# 476   2007-08-01  T138  41.726465 -87.585413           909           1
# 1753  2009-06-29  T900  41.974689 -87.890615           878           0
# 961   2007-08-28  T103  41.702724 -87.536497           822           1

# %%
train.head()
# Out:
#          Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 0  2007-05-29  T002  41.954690 -87.800991             2           0
# 1  2007-05-29  T007  41.994991 -87.769279             1           0
# 2  2007-05-29  T015  41.974089 -87.824812             5           0
# 3  2007-05-29  T045  41.921600 -87.666455             2           0
# 4  2007-05-29  T046  41.891118 -87.654491             1           0

# %%
train['WnvPresent'] = train[['WnvPresent']].apply(lambda x: [y if y <= 0 else 1 for y in x])

# %%
train.head(5)
# Out:
#          Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 0  2007-05-29  T002  41.954690 -87.800991             2           0
# 1  2007-05-29  T007  41.994991 -87.769279             1           0
# 2  2007-05-29  T015  41.974089 -87.824812             5           0
# 3  2007-05-29  T045  41.921600 -87.666455             2           0
# 4  2007-05-29  T046  41.891118 -87.654491             1           0

# %%
maps = alt.Chart(train).mark_circle(size = 80).encode(
    alt.X('Longitude', title = "Longitude", scale = alt.Scale(domain=[-88.1, -87.3])),
    alt.Y('Latitude', title = "Latitude", scale = alt.Scale(domain=[41.6, 42.1])),
).properties(title= "Locations of Mosquito Traps"
).interactive(
)
maps

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
#
# [5 rows x 22 columns]

# %%
weather.columns
# Out:
# Index(['Station', 'Date', 'Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint',
#        'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset', 'CodeSum', 'Depth',
#        'Water1', 'SnowFall', 'PrecipTotal', 'StnPressure', 'SeaLevel',
#        'ResultSpeed', 'ResultDir', 'AvgSpeed'],
#       dtype='object')

# %%
weather = weather.drop(['Depart', 'Sunrise', 'Sunset', 'Heat', 'Cool', "CodeSum", 'Depth', 'Water1'], axis = 1)
weather = weather[weather.Station != 2]

# %%
weather.SnowFall.unique()
# Out:
# array(['0.0', '  T', '0.1'], dtype=object)

# %%
weather.PrecipTotal.unique()
# Out:
# array(['0.00', '  T', '0.13', '0.38', '0.14', '0.07', '0.02', '1.01',
#        '0.04', '0.01', '0.19', '0.39', '0.42', '0.28', '0.58', '0.05',
#        '0.16', '0.15', '0.40', '0.30', '0.43', '0.11', '1.55', '0.17',
#        '0.03', '1.43', '0.26', '1.31', '0.06', '0.29', '0.41', '0.23',
#        '0.09', '1.33', '0.91', '0.37', '2.35', '0.24', '0.34', '0.18',
#        '0.36', '0.27', '0.33', '1.28', '0.76', '0.95', '0.08', '0.12',
#        '0.48', '0.52', '0.64', '1.24', '0.20', '0.72', '0.73', '1.61',
#        '0.74', '1.05', '2.43', '2.90', '1.23', '6.64', '1.44', '0.82',
#        '0.80', '0.32', '0.67', '0.55', '1.73', '0.44', '0.45', '3.97',
#        '0.25', '0.68', '0.63', '0.35', '0.93', '0.22', '0.75', '0.89',
#        '0.21', '0.46', '1.03', '0.60', '0.81', '0.97', '1.49', '1.02',
#        '0.59', '0.87', '0.85', '0.54', '0.79', '2.79', '3.64', '0.10',
#        '0.31', '2.24', '1.06', '1.88', '6.86', '0.71', '0.70', '1.11',
#        '0.65', '1.21', '0.77', '1.34', '0.47', '1.12', '0.57', '0.51',
#        '1.09', '0.56', '1.35', '0.84', '1.48', '0.92', '0.50', '1.04',
#        '2.09', '1.26', '2.60', '2.76', '0.98', '1.58'], dtype=object)

# %%
weather.WetBulb.unique()
# Out:
# array(['56', '47', '48', '50', '49', '46', '54', '62', '63', '60', '51',
#        '59', '61', '43', '53', '44', '58', '65', '66', '67', '55', '69',
#        '57', '64', '70', '72', '71', '68', '73', '74', '76', '52', '45',
#        '42', '39', '40', '41', '35', '33', '34', 'M', '32', '38', '36',
#        '78', '77', '75', '37'], dtype=object)

# %%
weather.SnowFall = weather.SnowFall.map(lambda x: np.nan if x == '  T' else float(x))
weather.PrecipTotal = weather.PrecipTotal.map(lambda x: np.nan if x == '  T' else float(x))
weather.WetBulb = weather.WetBulb.map(lambda x: np.nan if x == 'M' else float(x))
weather = weather.dropna()

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1298 entries, 0 to 2942
# Data columns (total 14 columns):
# Station        1298 non-null int64
# Date           1298 non-null object
# Tmax           1298 non-null int64
# Tmin           1298 non-null int64
# Tavg           1298 non-null object
# DewPoint       1298 non-null int64
# WetBulb        1298 non-null float64
# SnowFall       1298 non-null float64
# PrecipTotal    1298 non-null float64
# StnPressure    1298 non-null object
# SeaLevel       1298 non-null object
# ResultSpeed    1298 non-null float64
# ResultDir      1298 non-null int64
# AvgSpeed       1298 non-null object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 152.1+ KB

# %%
weather.describe()
# Out:
#        Station         Tmax         Tmin     DewPoint      WetBulb  \
# count   1298.0  1298.000000  1298.000000  1298.000000  1298.000000
# mean       1.0    76.197227    56.712635    53.473806    59.156394
# std        0.0    11.357630    10.248862    10.603225     9.221227
# min        1.0    44.000000    29.000000    22.000000    32.000000
# 25%        1.0    69.000000    49.000000    46.000000    53.000000
# 50%        1.0    78.500000    58.000000    54.000000    60.000000
# 75%        1.0    85.000000    65.000000    62.000000    66.000000
# max        1.0   103.000000    82.000000    75.000000    78.000000
#
#           SnowFall  PrecipTotal  ResultSpeed    ResultDir
# count  1298.000000  1298.000000  1298.000000  1298.000000
# mean      0.000077     0.147103     6.885516    17.568567
# std       0.002776     0.438141     3.585395    10.185799
# min       0.000000     0.000000     0.100000     1.000000
# 25%       0.000000     0.000000     4.300000     7.000000
# 50%       0.000000     0.000000     6.300000    19.000000
# 75%       0.000000     0.090000     8.975000    25.000000
# max       0.100000     6.860000    24.100000    36.000000

# %%
re_train = pd.read_csv('./train.csv')

# %%
re_train = re_train.drop(['Address', 'Street', 'Species', 'Block', 'AddressNumberAndStreet', 'AddressAccuracy'], axis = 1)
re_train = re_train.groupby(['Date', 'Trap', 'Latitude', 'Longitude']).sum().reset_index()
re_train['WnvPresent'] = re_train[['WnvPresent']].apply(lambda x: [y if y <= 0 else 1 for y in x])

# %%
re_train.describe()
# Out:
#           Latitude    Longitude  NumMosquitos   WnvPresent
# count  4616.000000  4616.000000   4616.000000  4616.000000
# mean     41.847684   -87.694223     29.254549     0.083406
# std       0.105060     0.081131    118.533327     0.276524
# min      41.644612   -87.930995      1.000000     0.000000
# 25%      41.754676   -87.747113      3.000000     0.000000
# 50%      41.862292   -87.694991      7.000000     0.000000
# 75%      41.944869   -87.648860     20.000000     0.000000
# max      42.017430   -87.531635   3002.000000     1.000000

# %%
re_train.head()
# Out:
#          Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent
# 0  2007-05-29  T002  41.954690 -87.800991             2           0
# 1  2007-05-29  T007  41.994991 -87.769279             1           0
# 2  2007-05-29  T015  41.974089 -87.824812             5           0
# 3  2007-05-29  T045  41.921600 -87.666455             2           0
# 4  2007-05-29  T046  41.891118 -87.654491             1           0

# %%
re_train.Date = pd.to_datetime(re_train.Date)
weather.Date = pd.to_datetime(weather.Date)

data = pd.merge(re_train, weather, how='outer', on='Date')
data = data.dropna()
data.head(10)
# Out:
#         Date  Trap   Latitude  Longitude  NumMosquitos  WnvPresent  Station  \
# 0 2007-05-29  T002  41.954690 -87.800991           2.0         0.0      1.0
# 1 2007-05-29  T007  41.994991 -87.769279           1.0         0.0      1.0
# 2 2007-05-29  T015  41.974089 -87.824812           5.0         0.0      1.0
# 3 2007-05-29  T045  41.921600 -87.666455           2.0         0.0      1.0
# 4 2007-05-29  T046  41.891118 -87.654491           1.0         0.0      1.0
# 5 2007-05-29  T048  41.867108 -87.654224           3.0         0.0      1.0
# 6 2007-05-29  T049  41.896282 -87.655232           1.0         0.0      1.0
# 7 2007-05-29  T050  41.919343 -87.694259           1.0         0.0      1.0
# 8 2007-05-29  T054  41.921965 -87.632085           5.0         0.0      1.0
# 9 2007-05-29  T086  41.688324 -87.676709           2.0         0.0      1.0
#
#    Tmax  Tmin Tavg  DewPoint  WetBulb  SnowFall  PrecipTotal StnPressure  \
# 0  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 1  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 2  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 3  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 4  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 5  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 6  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 7  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 8  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
# 9  88.0  60.0   74      58.0     65.0       0.0          0.0       29.39
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    30.11          5.8       18.0      6.5
# 1    30.11          5.8       18.0      6.5
# 2    30.11          5.8       18.0      6.5
# 3    30.11          5.8       18.0      6.5
# 4    30.11          5.8       18.0      6.5
# 5    30.11          5.8       18.0      6.5
# 6    30.11          5.8       18.0      6.5
# 7    30.11          5.8       18.0      6.5
# 8    30.11          5.8       18.0      6.5
# 9    30.11          5.8       18.0      6.5

# %%
columns = list(data.columns)
columns.remove('Date') 
columns.remove('Trap') 
columns.remove('WnvPresent') 
columns.remove('Station')
columns
# Out:
# ['Latitude',
#  'Longitude',
#  'NumMosquitos',
#  'Tmax',
#  'Tmin',
#  'Tavg',
#  'DewPoint',
#  'WetBulb',
#  'SnowFall',
#  'PrecipTotal',
#  'StnPressure',
#  'SeaLevel',
#  'ResultSpeed',
#  'ResultDir',
#  'AvgSpeed']

# %%
y = data['WnvPresent']
X = data[columns]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
test.head(5)
# Out:
#    Id        Date                                            Address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3   4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4   5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3        CULEX SALINARIUS     41   N OAK PARK AVE  T002
# 4         CULEX TERRITANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 2  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 3  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 4  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9

# %%
test = test.groupby(['Date', 'Trap', 'Latitude', 'Longitude']).sum().reset_index()
test.Date = pd.to_datetime(re_train.Date)
# test['WnvPresent'] = test[['WnvPresent']].apply(lambda x: [y if y <= 0 else 1 for y in x])
data_test = pd.merge(test, weather, how='outer', on='Date')
data_test = data_test.dropna()

# %%
X = X.apply(pd.to_numeric)

# %%
lin_reg = LinearRegression()
log_reg = LogisticRegression()

lin_reg.fit(X_train, y_train)
log_reg.fit(X_train, y_train)
# Out:
# C:\Users\colin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
lin_reg.score(X_train, y_train)
# Out:
# 0.13197555558261742

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.0324075059131933

# %%
lin_reg.coef_
# Out:
# array([ 9.48370034e-03, -2.71133730e-01,  7.30418346e-04, -4.79297872e-02,
#        -4.19171396e-02,  9.09997753e-02,  7.57633283e-03, -4.41925446e-03,
#        -1.80411242e-16, -3.46713274e-02, -1.16781400e+00,  1.27189075e+00,
#        -4.12901254e-03,  1.13461310e-03, -3.01170321e-03])

# %%
X.columns
# Out:
# Index(['Latitude', 'Longitude', 'NumMosquitos', 'Tmax', 'Tmin', 'Tavg',
#        'DewPoint', 'WetBulb', 'SnowFall', 'PrecipTotal', 'StnPressure',
#        'SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed'],
#       dtype='object')

# %%
pd.DataFrame({
    'features' : X.columns,
    'coefs' : lin_reg.coef_
})
# Out:
#         features         coefs
# 0       Latitude  9.483700e-03
# 1      Longitude -2.711337e-01
# 2   NumMosquitos  7.304183e-04
# 3           Tmax -4.792979e-02
# 4           Tmin -4.191714e-02
# 5           Tavg  9.099978e-02
# 6       DewPoint  7.576333e-03
# 7        WetBulb -4.419254e-03
# 8       SnowFall -1.804112e-16
# 9    PrecipTotal -3.467133e-02
# 10   StnPressure -1.167814e+00
# 11      SeaLevel  1.271891e+00
# 12   ResultSpeed -4.129013e-03
# 13     ResultDir  1.134613e-03
# 14      AvgSpeed -3.011703e-03

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.919772583701832

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.9242424242424242

# %%
log_reg.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'max_iter': 100,
#  'multi_class': 'warn',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'warn',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}
